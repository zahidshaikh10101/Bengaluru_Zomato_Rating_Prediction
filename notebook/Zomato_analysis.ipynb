# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dataset link:
# [Click Here](https://www.kaggle.com/datasets/rajeshrampure/zomato-dataset)

# %%
df=pd.read_csv(r'data/zomato.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
print(f" Rows in dataset : {df.shape[0]}\n Columns in dataset : {df.shape[1]}")
# Out:
#  Rows in dataset : 51717
#  Columns in dataset : 17

# %%
print("Information about dataset :\n")
df.info()
# Out:
# Information about dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
# ...

# %%
print("Descriptive Statistics of dataset :\n",df.describe())
# Out:
# Descriptive Statistics of dataset :
#                votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
print('Number of unique values in each columns: ',df.nunique())
# Out:
# Number of unique values in each columns:  url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              64
# votes                           2328
# phone                          14926
# location                          93
# rest_type                         93
# dish_liked                      5271
# cuisines                        2723
# approx_cost(for two people)       70
# reviews_list                   22513
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %%
print("Columns in dataset :\n",df.columns)
# Out:
# Columns in dataset :
#  Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
df1.drop(columns=['url', 'address', 'name', 'phone', 'dish_liked',
                  'reviews_list', 'menu_item', 'listed_in(city)'],inplace=True,axis=1)
df1.head()
# Out:
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines approx_cost(for two people) listed_in(type)
# 0  North Indian, Mughlai, Chinese                         800          Buffet
# 1     Chinese, North Indian, Thai                         800          Buffet
# 2          Cafe, Mexican, Italian                         800          Buffet
# 3      South Indian, North Indian                         300          Buffet
# 4        North Indian, Rajasthani                         600          Buffet

# %%
df1 = df1.rename(columns={"rate":"rating", "approx_cost(for two people)":"cost_for_two",
                          "listed_in(type)":"type", "listed_in(city)":"location",
                          "book_table":"reservations", "online_order":"online"})
df1.tail(15)
# Out:
#       online reservations  rating  votes                    location  \
# 51702     No           No  4.0 /5   1094                  Whitefield
# 51703    Yes          Yes  3.9 /5    548                  Whitefield
# 51704     No          Yes  4.0 /5    189                  Whitefield
# 51705    Yes          Yes  3.8 /5    128                  Whitefield
# 51706     No           No  3.7 /5     27                  Whitefield
# 51707     No           No  3.9 /5     77                  Whitefield
# 51708     No           No  2.8 /5    161                  Whitefield
# 51709     No           No  3.7 /5     34                  Whitefield
# 51710     No           No     NaN      0                  Whitefield
# 51711     No           No  2.5 /5     81                  Whitefield
# 51712     No           No  3.6 /5     27                  Whitefield
# 51713     No           No     NaN      0                  Whitefield
# 51714     No           No     NaN      0                  Whitefield
# ...

# %%
df1.columns = df1.columns.str.replace(" ","")
df1.head(7)
# Out:
#   online reservations rating  votes      location            rest_type  \
# 0    Yes          Yes  4.1/5    775  Banashankari        Casual Dining
# 1    Yes           No  4.1/5    787  Banashankari        Casual Dining
# 2    Yes           No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3     No           No  3.7/5     88  Banashankari          Quick Bites
# 4     No           No  3.8/5    166  Basavanagudi        Casual Dining
# 5    Yes           No  3.8/5    286  Basavanagudi        Casual Dining
# 6     No           No  3.6/5      8   Mysore Road        Casual Dining
#
#                                       cuisines cost_for_two    type
# 0               North Indian, Mughlai, Chinese          800  Buffet
# 1                  Chinese, North Indian, Thai          800  Buffet
# 2                       Cafe, Mexican, Italian          800  Buffet
# 3                   South Indian, North Indian          300  Buffet
# ...

# %%
df1.shape
# Out:
# (51717, 9)

# %%
print("Number of duplicates values: ",df1.duplicated().sum())
print(df1.shape)
print('*' * 70)
df1.drop_duplicates(inplace=True)
print("Number of duplicates values: ",df1.duplicated().sum())
print(df1.shape)
# Out:
# Number of duplicates values:  16946
# (51717, 9)
# **********************************************************************
# Number of duplicates values:  0
# (34771, 9)

# %%
df2 = df1.copy()

# %%
df2.dtypes
# Out:
# online          object
# reservations    object
# rating          object
# votes            int64
# location        object
# rest_type       object
# cuisines        object
# cost_for_two    object
# type            object
# dtype: object

# %%
print("There are {} values that are unique in Online Columns".format(len(df2["online"].unique())))
print("Number of unique values in Online Columns: ",df2['online'].unique())
print('-' * 75)
print("Number of values in online sorted uniquely: ",df2['online'].value_counts())
# Out:
# There are 2 values that are unique in Online Columns
# Number of unique values in Online Columns:  ['Yes' 'No']
# ---------------------------------------------------------------------------
# Number of values in online sorted uniquely:  online
# Yes    20772
# No     13999
# Name: count, dtype: int64

# %%
print("There are {} values that are unique in Reservations Columns".format(len(df2["reservations"].unique())))
print("Number of unique values in Reservations Columns: ",df2['reservations'].unique())
print('-' * 75)
print("Number of values in reservations sorted uniquely: ",df2['reservations'].value_counts())
# Out:
# There are 2 values that are unique in Reservations Columns
# Number of unique values in Reservations Columns:  ['Yes' 'No']
# ---------------------------------------------------------------------------
# Number of values in reservations sorted uniquely:  reservations
# No     29369
# Yes     5402
# Name: count, dtype: int64

# %%
df2['rating'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df2['rating'] = df2['rating'].str.split('/5').str[0].str.strip()
df2['rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5', nan,
#        '2.6', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3', '-',
#        '4.8', '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df2.drop(df2[(df2['rating'] == 'NEW') | (df2['rating'] == '-')].index, inplace=True)
df2['rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '2.9', '3.5', nan, '2.6',
#        '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3', '4.8',
#        '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df2['rating'] = df2['rating'].astype(float)
df2['rating'].dtypes
# Out:
# dtype('float64')

# %%
print("Number of Null Values in rating: ",df2['rating'].isnull().sum())
# Out:
# Number of Null Values in rating:  3567

# %%
print(df2['rating'].describe())
print('-' * 75)
print("Mean of Rating: ",df2['rating'].mean())
print("Median of Rating: ",df2['rating'].median())
print("Mode of Rating: ",df2['rating'].mode())
# Out:
# count    29897.000000
# mean         3.730552
# std          0.453051
# min          1.800000
# 25%          3.400000
# 50%          3.800000
# 75%          4.100000
# max          4.900000
# Name: rating, dtype: float64
# ---------------------------------------------------------------------------
# Mean of Rating:  3.730551560357226
# Median of Rating:  3.8
# Mode of Rating:  0    3.9
# Name: rating, dtype: float64

# %%
df2['rating'].fillna(df2['rating'].mean(), inplace = True)
print("Number of Null Values in rating: ",df2['rating'].isnull().sum())
# Out:
# Number of Null Values in rating:  0

# %%
print(df2['votes'].describe())
print('-' * 75)
print("Mean of Votes: ",df2['votes'].mean())
print("Median of Votes: ",df2['votes'].median())
print("Mode of Votes: ",df2['votes'].mode())
# Out:
# count    33464.000000
# mean       379.089708
# std        958.335924
# min          0.000000
# 25%         14.000000
# 50%         67.000000
# 75%        293.000000
# max      16832.000000
# Name: votes, dtype: float64
# ---------------------------------------------------------------------------
# Mean of Votes:  379.08970834329426
# Median of Votes:  67.0
# Mode of Votes:  0    0
# Name: votes, dtype: int64

# %%
print("Number of Null Values in votes: ",df2['votes'].isnull().sum())
# Out:
# Number of Null Values in votes:  0

# %%
print("Number of values in location sorted uniquely: ",df2['location'].value_counts())
# Out:
# Number of values in location sorted uniquely:  location
# BTM                     2366
# Whitefield              1845
# Indiranagar             1711
# HSR                     1679
# Marathahalli            1609
#                         ...
# West Bangalore             4
# Nagarbhavi                 4
# Rajarajeshwari Nagar       2
# Jakkur                     1
# Peenya                     1
# Name: count, Length: 93, dtype: int64

# %%
print("Number of values in rest_type sorted uniquely: ",df2['rest_type'].value_counts())
# Out:
# Number of values in rest_type sorted uniquely:  rest_type
# Quick Bites                   11367
# Casual Dining                  7411
# Cafe                           2526
# Dessert Parlor                 1448
# Delivery                       1438
#                               ...
# Bakery, Sweet Shop                1
# Mess, Quick Bites                 1
# Quick Bites, Kiosk                1
# Dessert Parlor, Food Court        1
# Sweet Shop, Dessert Parlor        1
# Name: count, Length: 93, dtype: int64

# %%
rest_type = df2["rest_type"].value_counts(ascending = False)
rest_less_than_500 = rest_type[rest_type < 500]
rest_less_than_500
# Out:
# rest_type
# Bar                           477
# Beverage Shop                 455
# Food Court                    409
# Bar, Casual Dining            345
# Lounge                        307
#                              ...
# Bakery, Sweet Shop              1
# Mess, Quick Bites               1
# Quick Bites, Kiosk              1
# Dessert Parlor, Food Court      1
# Sweet Shop, Dessert Parlor      1
# Name: count, Length: 85, dtype: int64

# %%
def rest_type(data):
    if data in rest_less_than_500:
        return "Other"
    else:
        return data

# %%
df2["rest_type"] = df2["rest_type"].apply(rest_type)
print("Number of values in rest_type sorted uniquely: ",df2['rest_type'].value_counts())
# Out:
# Number of values in rest_type sorted uniquely:  rest_type
# Quick Bites           11367
# Casual Dining          7411
# Other                  6385
# Cafe                   2526
# Dessert Parlor         1448
# Delivery               1438
# Takeaway, Delivery     1110
# Casual Dining, Bar      949
# Bakery                  686
# Name: count, dtype: int64

# %%
print("Number of Null Values in rest_type: ",df2['rest_type'].isnull().sum())
# Out:
# Number of Null Values in rest_type:  144

# %%
df2['rest_type'].fillna("Other", inplace = True)
print("Number of Null Values in rest_type: ",df2['rest_type'].isnull().sum())
# Out:
# Number of Null Values in rest_type:  0

# %%
print("Number of values in rest_type sorted uniquely: ",df2['rest_type'].value_counts())
# Out:
# Number of values in rest_type sorted uniquely:  rest_type
# Quick Bites           11367
# Casual Dining          7411
# Other                  6529
# Cafe                   2526
# Dessert Parlor         1448
# Delivery               1438
# Takeaway, Delivery     1110
# Casual Dining, Bar      949
# Bakery                  686
# Name: count, dtype: int64

# %%
sns.boxplot(x=df2['cost_for_two'])
# Out:
# <Axes: xlabel='cost_for_two'>

# %%
df2['cost_for_two'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '1,100', '1,600', '230',
#        '130', '80', '50', '190', '1,700', nan, '180', '1,350', '2,200',
#        '1,400', '2,000', '1,800', '1,900', '330', '2,500', '2,100',
#        '3,000', '2,800', '3,400', '40', '1,250', '3,500', '4,000',
#        '2,400', '2,600', '120', '1,450', '469', '70', '3,200', '60',
#        '240', '6,000', '1,050', '2,300', '4,100', '5,000', '3,700',
#        '1,650', '2,700', '4,500', '140', '360'], dtype=object)

# %%
df2["cost_for_two"] = df2["cost_for_two"].str.replace(',','')
df2["cost_for_two"] = df2["cost_for_two"].astype(float)
df2['cost_for_two'].unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199., 1100., 1600.,  230.,  130.,
#          80.,   50.,  190., 1700.,   nan,  180., 1350., 2200., 1400.,
#        2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800., 3400.,
#          40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,  469.,
#          70., 3200.,   60.,  240., 6000., 1050., 2300., 4100., 5000.,
#        3700., 1650., 2700., 4500.,  140.,  360.])

# %%
print("Number of Null Values in cost_for_two: ",df2['cost_for_two'].isnull().sum())
# Out:
# Number of Null Values in cost_for_two:  205

# %%
print(df2['cost_for_two'].describe())
print('-' * 75)
print("Mean of Cost_for_two: ",df2['cost_for_two'].mean())
print("Median of Cost_for_two: ",df2['cost_for_two'].median())
print("Mode of Cost_for_two: ",df2['cost_for_two'].mode())
# Out:
# count    33259.000000
# mean       602.067921
# std        466.805016
# min         40.000000
# 25%        300.000000
# 50%        450.000000
# 75%        750.000000
# max       6000.000000
# Name: cost_for_two, dtype: float64
# ---------------------------------------------------------------------------
# Mean of Cost_for_two:  602.0679214648667
# Median of Cost_for_two:  450.0
# Mode of Cost_for_two:  0    400.0
# Name: cost_for_two, dtype: float64

# %%
df2['cost_for_two'].fillna(df2['cost_for_two'].median(), inplace = True)
print("Number of Null Values in cost_for_two: ",df2['cost_for_two'].isnull().sum())
# Out:
# Number of Null Values in cost_for_two:  0

# %%
print("Number of values in type sorted uniquely: ",df2['type'].value_counts())
# Out:
# Number of values in type sorted uniquely:  type
# Delivery              15424
# Dine-out              12319
# Desserts               2378
# Cafes                  1199
# Drinks & nightlife      892
# Buffet                  664
# Pubs and bars           588
# Name: count, dtype: int64

# %%
df3 = df2.copy()

# %%
df3.iloc[2500:2700,]
# Out:
#      online reservations    rating  votes       location      rest_type  \
# 2936     No           No  3.730552      0   Basavanagudi    Quick Bites
# 2939    Yes          Yes  3.700000     49            BTM           Cafe
# 2940    Yes          Yes  3.800000    361      Jayanagar  Casual Dining
# 2941    Yes           No  3.900000     36  Wilson Garden    Quick Bites
# 2942    Yes          Yes  4.300000    548   Shanti Nagar  Casual Dining
# ...     ...          ...       ...    ...            ...            ...
# 3309     No           No  3.400000     26   Basavanagudi  Casual Dining
# 3310     No          Yes  3.700000     64   Basavanagudi          Other
# 3311    Yes           No  4.100000    216   Basavanagudi           Cafe
# 3312    Yes           No  3.700000    514   Basavanagudi           Cafe
# 3313    Yes           No  3.700000     54   Basavanagudi           Cafe
#
#                                         cuisines  cost_for_two      type
# ...

# %%
pd.crosstab(df3['type'],df3['location'], margins=True, margins_name='Total')
# Out:
# location             BTM  Banashankari  Banaswadi  Bannerghatta Road  \
# type
# Buffet                15             5          0                  8
# Cafes                 44            24         13                 25
# Delivery            1357           229        156                491
# Desserts             110            43         19                 88
# Dine-out             812           229        230                384
# Drinks & nightlife    15             7          4                  9
# Pubs and bars         13             0          1                  2
# Total               2366           537        423               1007
#
# location            Basavanagudi  Basaveshwara Nagar  Bellandur  Bommanahalli  \
# type
# Buffet                         4                   2         28             2
# Cafes                          8                   5         32             1
# Delivery                     188                  71        492            94
# ...

# %%
pd.crosstab(df3['online'],df3['type'], margins=True, margins_name='Total')
# Out:
# type    Buffet  Cafes  Delivery  Desserts  Dine-out  Drinks & nightlife  \
# online
# No         385    532      4049      1159      6078                 676
# Yes        279    667     11375      1219      6241                 216
# Total      664   1199     15424      2378     12319                 892
#
# type    Pubs and bars  Total
# online
# No                415  13294
# Yes               173  20170
# Total             588  33464

# %%
pd.crosstab(df3['reservations'],df3['type'], margins=True, margins_name='Total')
# Out:
# type          Buffet  Cafes  Delivery  Desserts  Dine-out  Drinks & nightlife  \
# reservations
# No               219    968     13924      2263     10230                 303
# Yes              445    231      1500       115      2089                 589
# Total            664   1199     15424      2378     12319                 892
#
# type          Pubs and bars  Total
# reservations
# No                      227  28134
# Yes                     361   5330
# Total                   588  33464

# %%
df3.tail()
# Out:
#       online reservations    rating  votes                    location  \
# 51712     No           No  3.600000     27                  Whitefield
# 51713     No           No  3.730552      0                  Whitefield
# 51714     No           No  3.730552      0                  Whitefield
# 51715     No          Yes  4.300000    236  ITPL Main Road, Whitefield
# 51716     No           No  3.400000     13  ITPL Main Road, Whitefield
#
#       rest_type                                cuisines  cost_for_two  \
# 51712     Other                             Continental        1500.0
# 51713     Other                             Finger Food         600.0
# 51714     Other                             Finger Food        2000.0
# 51715     Other                             Finger Food        2500.0
# 51716     Other  Finger Food, North Indian, Continental        1500.0
#
#                 type
# 51712  Pubs and bars
# 51713  Pubs and bars
# 51714  Pubs and bars
# 51715  Pubs and bars
# ...

# %%
rating_categories = df3['rating']
rating_categories = rating_categories.dropna()

bins = [1,2,3,4,5]
binlabels = ['Poor', 'Unsatisfactory', 'Satisfactory', 'Outstanding']

categories = pd.cut(rating_categories,bins,labels = binlabels)
categories.head(20)
# Out:
# 0      Outstanding
# 1      Outstanding
# 2     Satisfactory
# 3     Satisfactory
# 4     Satisfactory
# 5     Satisfactory
# 6     Satisfactory
# 7      Outstanding
# 8     Satisfactory
# 9      Outstanding
# 10     Outstanding
# 11     Outstanding
# 12     Outstanding
# 13    Satisfactory
# 14    Satisfactory
# 15    Satisfactory
# 16    Satisfactory
# 17    Satisfactory
# 18    Satisfactory
# 19    Satisfactory
# Name: rating, dtype: category
# Categories (4, object): ['Poor' < 'Unsatisfactory' < 'Satisfactory' < 'Outstanding']

# %%
df3['rating_categories'] = categories
df3.tail(5)
# Out:
#       online reservations    rating  votes                    location  \
# 51712     No           No  3.600000     27                  Whitefield
# 51713     No           No  3.730552      0                  Whitefield
# 51714     No           No  3.730552      0                  Whitefield
# 51715     No          Yes  4.300000    236  ITPL Main Road, Whitefield
# 51716     No           No  3.400000     13  ITPL Main Road, Whitefield
#
#       rest_type                                cuisines  cost_for_two  \
# 51712     Other                             Continental        1500.0
# 51713     Other                             Finger Food         600.0
# 51714     Other                             Finger Food        2000.0
# 51715     Other                             Finger Food        2500.0
# 51716     Other  Finger Food, North Indian, Continental        1500.0
#
#                 type rating_categories
# 51712  Pubs and bars      Satisfactory
# ...

# %%
df3.describe()
# Out:
#              rating         votes  cost_for_two
# count  33464.000000  33464.000000  33464.000000
# mean       3.730552    379.089708    601.136355
# std        0.428224    958.335924    465.524205
# min        1.800000      0.000000     40.000000
# 25%        3.500000     14.000000    300.000000
# 50%        3.730552     67.000000    450.000000
# 75%        4.000000    293.000000    750.000000
# max        4.900000  16832.000000   6000.000000

# %%
df4 = df3.copy()

# %%
df4.columns
# Out:
# Index(['online', 'reservations', 'rating', 'votes', 'location', 'rest_type',
#        'cuisines', 'cost_for_two', 'type', 'rating_categories'],
#       dtype='object')

# %%
df4.drop(columns='rating_categories', inplace=True)

# %%
print('-' * 100)
print("Categories in 'online' variable:     ",end=" " )
print(df4['online'].unique())
print('-' * 100)
print("Categories in 'reservations' variable:  ",end=" ")
print(df4['reservations'].unique())
print('-' * 100)
print("Categories in 'location' variable:",end=" " )
print(df4['location'].unique())
print('-' * 100)
print("Categories in 'rest_type' variable:     ",end=" " )
print(df4['rest_type'].unique())
print('-' * 100)
print("Categories in 'cuisines' variable:     ",end=" " )
print(df4['cuisines'].unique())
print('-' * 100)
print("Categories in 'type' variable:     ",end=" " )
print(df4['type'].unique())
print('-' * 100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Categories in 'online' variable:      ['Yes' 'No']
# ----------------------------------------------------------------------------------------------------
# Categories in 'reservations' variable:   ['Yes' 'No']
# ----------------------------------------------------------------------------------------------------
# Categories in 'location' variable: ['Banashankari' 'Basavanagudi' 'Mysore Road' 'Jayanagar'
#  'Kumaraswamy Layout' 'Rajarajeshwari Nagar' 'Vijay Nagar' 'Uttarahalli'
#  'JP Nagar' 'South Bangalore' 'City Market' 'Nagarbhavi'
#  'Bannerghatta Road' 'BTM' 'Kanakapura Road' 'Bommanahalli' nan
#  'Electronic City' 'HSR' 'Marathahalli' 'Sarjapur Road' 'Wilson Garden'
#  'Shanti Nagar' 'Koramangala 5th Block' 'Koramangala 8th Block'
#  'Richmond Road' 'Koramangala 7th Block' 'Jalahalli'
#  'Koramangala 4th Block' 'Bellandur' 'Whitefield' 'East Bangalore'
# ...

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df4.columns if df4[feature].dtype != 'O']
categorical_features = [feature for feature in df4.columns if df4[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 3 numerical features : ['rating', 'votes', 'cost_for_two']
#
# We have 6 categorical features : ['online', 'reservations', 'location', 'rest_type', 'cuisines', 'type']

# %%
df4.iloc[1050:1070]
# Out:
#      online reservations    rating  votes           location      rest_type  \
# 1102    Yes           No  3.600000     11                BTM          Other
# 1103    Yes           No  3.730552      0                BTM    Quick Bites
# 1104    Yes           No  4.000000     35                BTM          Other
# 1105    Yes           No  3.000000     45  Bannerghatta Road       Delivery
# 1106    Yes           No  3.200000     56  Bannerghatta Road    Quick Bites
# 1107    Yes           No  4.000000    869                BTM       Delivery
# 1108    Yes           No  3.200000     34  Bannerghatta Road    Quick Bites
# 1109    Yes           No  4.000000    153           JP Nagar    Quick Bites
# 1110    Yes           No  3.700000    139  Bannerghatta Road    Quick Bites
# 1111    Yes           No  3.100000     10           JP Nagar    Quick Bites
# 1113    Yes           No  3.700000    181  Bannerghatta Road       Delivery
# ...

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df4,x='rating',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df4,x='rating',kde=True,hue='reservations')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df4,x='cost_for_two',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df4,x='cost_for_two',kde=True,hue='reservations')
plt.show()

# %%
plt.subplots(1,3,figsize=(16,5))
plt.subplot(131)
sns.boxplot(df4['rating'],color='skyblue')
plt.subplot(132)
sns.boxplot(df4['votes'],color='hotpink')
plt.subplot(133)
sns.boxplot(df4['cost_for_two'],color='lightgreen')
plt.show()

# %%
df4.to_csv('data/Updated_Zomato_Data.csv')
