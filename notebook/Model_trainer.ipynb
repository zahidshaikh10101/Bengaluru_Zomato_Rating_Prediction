# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import warnings

# %%
df = pd.read_csv('data/Updated_Zomato_Data.csv', header=0, index_col=0)

# %%
df.head(20)
# Out:
#    online reservations  rating  votes      location      rest_type  \
# 0     Yes          Yes     4.1    775  Banashankari  Casual Dining
# 1     Yes           No     4.1    787  Banashankari  Casual Dining
# 2     Yes           No     3.8    918  Banashankari          Other
# 3      No           No     3.7     88  Banashankari    Quick Bites
# 4      No           No     3.8    166  Basavanagudi  Casual Dining
# 5     Yes           No     3.8    286  Basavanagudi  Casual Dining
# 6      No           No     3.6      8   Mysore Road  Casual Dining
# 7     Yes          Yes     4.6   2556  Banashankari          Other
# 8     Yes           No     4.0    324  Banashankari           Cafe
# 9     Yes           No     4.2    504  Banashankari           Cafe
# 10    Yes           No     4.1    402  Banashankari           Cafe
# 11    Yes          Yes     4.2    150  Banashankari           Cafe
# 12    Yes          Yes     4.2    164  Banashankari           Cafe
# 13     No           No     4.0    424  Banashankari           Cafe
# 15    Yes           No     3.8     90  Banashankari           Cafe
# 16    Yes           No     3.9    133  Banashankari           Cafe
# 17    Yes           No     3.8    144  Banashankari           Cafe
# 18     No           No     3.9     93  Banashankari           Cafe
# 19    Yes           No     3.1     13  Banashankari           Cafe
# 20    Yes           No     3.0     62  Banashankari           Cafe
#
#     cost_for_two
# 0          800.0
# 1          800.0
# 2          800.0
# 3          300.0
# 4          600.0
# 5          600.0
# 6          800.0
# 7          600.0
# 8          700.0
# 9          550.0
# 10         500.0
# 11         600.0
# 12         500.0
# 13         450.0
# 15         650.0
# 16         800.0
# 17         700.0
# 18         300.0
# 19         400.0
# 20         400.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

cat_features = df.select_dtypes(include="object").columns
num_features = df.select_dtypes(exclude="object").columns

for x in cat_features:
    df[x]=le.fit_transform(df[x])
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print("Feature",x)
    print("Mapping", le_name_mapping)
# Out:
# Feature online
# Mapping {'No': 0, 'Yes': 1}
# Feature reservations
# Mapping {'No': 0, 'Yes': 1}
# Feature location
# Mapping {'BTM': 0, 'Banashankari': 1, 'Banaswadi': 2, 'Bannerghatta Road': 3, 'Basavanagudi': 4, 'Basaveshwara Nagar': 5, 'Bellandur': 6, 'Bommanahalli': 7, 'Brigade Road': 8, 'Brookefield': 9, 'CV Raman Nagar': 10, 'Central Bangalore': 11, 'Church Street': 12, 'City Market': 13, 'Commercial Street': 14, 'Cunningham Road': 15, 'Domlur': 16, 'East Bangalore': 17, 'Ejipura': 18, 'Electronic City': 19, 'Frazer Town': 20, 'HBR Layout': 21, 'HSR': 22, 'Hebbal': 23, 'Hennur': 24, 'Hosur Road': 25, 'ITPL Main Road, Whitefield': 26, 'Indiranagar': 27, 'Infantry Road': 28, 'JP Nagar': 29, 'Jakkur': 30, 'Jalahalli': 31, 'Jayanagar': 32, 'Jeevan Bhima Nagar': 33, 'KR Puram': 34, 'Kaggadasapura': 35, 'Kalyan Nagar': 36, 'Kammanahalli': 37, 'Kanakapura Road': 38, 'Kengeri': 39, 'Koramangala': 40, 'Koramangala 1st Block': 41, 'Koramangala 2nd Block': 42, 'Koramangala 3rd Block': 43, 'Koramangala 4th Block': 44, 'Koramangala 5th Block': 45, 'Koramangala 6th Block': 46, 'Koramangala 7th Block': 47, 'Koramangala 8th Block': 48, 'Kumaraswamy Layout': 49, 'Langford Town': 50, 'Lavelle Road': 51, 'MG Road': 52, 'Magadi Road': 53, 'Majestic': 54, 'Malleshwaram': 55, 'Marathahalli': 56, 'Mysore Road': 57, 'Nagarbhavi': 58, 'Nagawara': 59, 'New BEL Road': 60, 'North Bangalore': 61, 'Old Airport Road': 62, 'Old Madras Road': 63, 'Peenya': 64, 'RT Nagar': 65, 'Race Course Road': 66, 'Rajajinagar': 67, 'Rajarajeshwari Nagar': 68, 'Rammurthy Nagar': 69, 'Residency Road': 70, 'Richmond Road': 71, 'Sadashiv Nagar': 72, 'Sahakara Nagar': 73, 'Sanjay Nagar': 74, 'Sankey Road': 75, 'Sarjapur Road': 76, 'Seshadripuram': 77, 'Shanti Nagar': 78, 'Shivajinagar': 79, 'South Bangalore': 80, 'St. Marks Road': 81, 'Thippasandra': 82, 'Ulsoor': 83, 'Uttarahalli': 84, 'Varthur Main Road, Whitefield': 85, 'Vasanth Nagar': 86, 'Vijay Nagar': 87, 'West Bangalore': 88, 'Whitefield': 89, 'Wilson Garden': 90, 'Yelahanka': 91, 'Yeshwantpur': 92, nan: 93}
# Feature rest_type
# Mapping {'Cafe': 0, 'Casual Dining': 1, 'Delivery': 2, 'Dessert Parlor': 3, 'Other': 4, 'Quick Bites': 5, 'Takeaway, Delivery': 6}

# %%
X = df.drop(columns=['rating'],axis=1)
X
# Out:
#        online  reservations  votes  location  rest_type  cost_for_two
# 0           1             1    775         1          1         800.0
# 1           1             0    787         1          1         800.0
# 2           1             0    918         1          4         800.0
# 3           0             0     88         1          5         300.0
# 4           0             0    166         4          1         600.0
# ...       ...           ...    ...       ...        ...           ...
# 51631       0             0      5         9          5         250.0
# 51632       0             0      4        34          5         350.0
# 51641       0             0      4         9          5         450.0
# 51677       0             0     81        89          4         800.0
# 51714       0             0      0        89          4        2000.0
#
# [20751 rows x 6 columns]

# %%
y = df['rating']
y
# Out:
# 0        4.100000
# 1        4.100000
# 2        3.800000
# 3        3.700000
# 4        3.800000
#            ...
# 51631    3.400000
# 51632    3.300000
# 51641    3.200000
# 51677    2.500000
# 51714    3.717349
# Name: rating, Length: 20751, dtype: float64

# %%
print(X.shape)
print(y.shape)
# Out:
# (20751, 6)
# (20751,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
print(X)
# Out:
# [[ 0.7773365   2.45549823  0.46010517 -1.34021568 -1.28306354  0.47216483]
#  [ 0.7773365  -0.40724933  0.47336717 -1.34021568 -1.28306354  0.47216483]
#  [ 0.7773365  -0.40724933  0.61814398 -1.34021568  0.35324069  0.47216483]
#  ...
#  [-1.28644416 -0.40724933 -0.39197817 -1.04522131  0.89867543 -0.28136634]
#  [-1.28644416 -0.40724933 -0.30688035  1.9047224   0.35324069  0.47216483]
#  [-1.28644416 -0.40724933 -0.39639883  1.9047224   0.35324069  3.05570029]]

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)
print("X_train: ",X_train.shape)
print("X_test: ",X_test.shape)
print("y_train: ",y_train.shape)
print("y_test: ",y_test.shape)
# Out:
# X_train:  (16600, 6)
# X_test:  (4151, 6)
# y_train:  (16600,)
# y_test:  (4151,)

# %%
def evaluate_model(true,predicted):
    mae = mean_absolute_error(true,predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression" : LinearRegression(),
    "Lasso" : Lasso(),
    "Ridge" : Ridge(),
    "K-Neighbors Regressor" : KNeighborsRegressor(),
    "Decision Tree Regressor" : DecisionTreeRegressor(),
    "Random Forest Regressor" : RandomForestRegressor(n_estimators=500, random_state=10),
    "Extra Tree Regressor" : ExtraTreesRegressor(n_estimators=500, random_state=10),
    "XGBRegressor" : XGBRegressor(),
    "CatBoosting Regressor" : CatBoostRegressor(verbose=False),
    "AdaBoost Regressor" : AdaBoostRegressor(), 
    "Support Vector Regressor" : SVR()
}

model_list = []
r2_list = []

len_models = len(list(models))

for i in range(len_models):
    model = list(models.values())[i]
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print("Model performance for Training set")
    print(" - Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print(" - Mean Absolute Error: {:.4f}".format(model_train_mae))
    print(" - R2 Score: {:.4f}".format(model_train_r2))

    print('-' * 37)

    print("Model performance for Testing set")
    print(" - Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print(" - Mean Absolute Error: {:.4f}".format(model_test_mae))
    print(" - R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)

    print('=' * 37)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
#  - Root Mean Squared Error: 0.3643
#  - Mean Absolute Error: 0.2806
#  - R2 Score: 0.2886
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3657
#  - Mean Absolute Error: 0.2813
#  - R2 Score: 0.2888
# =====================================
#
#
# Lasso
# Model performance for Training set
#  - Root Mean Squared Error: 0.4319
#  - Mean Absolute Error: 0.3335
#  - R2 Score: 0.0000
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.4337
#  - Mean Absolute Error: 0.3350
#  - R2 Score: -0.0000
# =====================================
#
#
# Ridge
# Model performance for Training set
#  - Root Mean Squared Error: 0.3643
#  - Mean Absolute Error: 0.2806
#  - R2 Score: 0.2886
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3657
#  - Mean Absolute Error: 0.2813
#  - R2 Score: 0.2888
# =====================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.2462
#  - Mean Absolute Error: 0.1738
#  - R2 Score: 0.6750
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3158
#  - Mean Absolute Error: 0.2279
#  - R2 Score: 0.4696
# =====================================
#
#
# Decision Tree Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.0377
#  - Mean Absolute Error: 0.0073
#  - R2 Score: 0.9924
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3129
#  - Mean Absolute Error: 0.1515
#  - R2 Score: 0.4795
# =====================================
#
#
# Random Forest Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.0902
#  - Mean Absolute Error: 0.0551
#  - R2 Score: 0.9564
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.2352
#  - Mean Absolute Error: 0.1428
#  - R2 Score: 0.7058
# =====================================
#
#
# Extra Tree Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.0377
#  - Mean Absolute Error: 0.0073
#  - R2 Score: 0.9924
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.2246
#  - Mean Absolute Error: 0.1164
#  - R2 Score: 0.7318
# =====================================
#
#
# XGBRegressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.2224
#  - Mean Absolute Error: 0.1550
#  - R2 Score: 0.7349
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.2735
#  - Mean Absolute Error: 0.1883
#  - R2 Score: 0.6023
# =====================================
#
#
# CatBoosting Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.2583
#  - Mean Absolute Error: 0.1822
#  - R2 Score: 0.6424
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.2824
#  - Mean Absolute Error: 0.1987
#  - R2 Score: 0.5760
# =====================================
#
#
# AdaBoost Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.3667
#  - Mean Absolute Error: 0.2984
#  - R2 Score: 0.2792
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3695
#  - Mean Absolute Error: 0.3005
#  - R2 Score: 0.2739
# =====================================
#
#
# Support Vector Regressor
# Model performance for Training set
#  - Root Mean Squared Error: 0.3284
#  - Mean Absolute Error: 0.2351
#  - R2 Score: 0.4217
# -------------------------------------
# Model performance for Testing set
#  - Root Mean Squared Error: 0.3308
#  - Mean Absolute Error: 0.2381
#  - R2 Score: 0.4179
# =====================================

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=["Model Name", "R2_Score"]).sort_values(by=["R2_Score"], ascending=False)
# Out:
#                   Model Name  R2_Score
# 6       Extra Tree Regressor  0.731785
# 5    Random Forest Regressor  0.705823
# 7               XGBRegressor  0.602302
# 8      CatBoosting Regressor  0.576050
# 4    Decision Tree Regressor  0.479478
# 3      K-Neighbors Regressor  0.469606
# 10  Support Vector Regressor  0.417950
# 2                      Ridge  0.288812
# 0          Linear Regression  0.288811
# 9         AdaBoost Regressor  0.273874
# 1                      Lasso -0.000006

# %%
model_DT = DecisionTreeRegressor()
model_DT.fit(X_train,y_train)
y_pred = model_DT.predict(X_test)
print(list(zip(df.columns[:-1],model_DT.feature_importances_)))
# Out:
# [('online', 0.021956032148997034), ('reservations', 0.019039972992423652), ('rating', 0.612093936909857), ('votes', 0.1596433593179052), ('location', 0.07103139058011229), ('rest_type', 0.11623530805070476)]
